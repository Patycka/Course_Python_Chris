# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
deniro_csv = "deniro.csv"

deniro_data = pd.read_csv(deniro_csv, sep=",", quotechar='"', skipinitialspace=True)
print(deniro_data)
# Out:
#     Year  Score          Title
# 0   1968     86      Greetings
# 1   1970     17    Bloody Mama
# 2   1970     73       Hi, Mom!
# 3   1971     40    Born to Win
# 4   1973     98   Mean Streets
# ..   ...    ...            ...
# 82  2014      9    The Bag Man
# 83  2015     60            Joy
# 84  2015     26          Heist
# 85  2015     61     The Intern
# 86  2016     11  Dirty Grandpa
#
# [87 rows x 3 columns]

# %%
deniro_sorted_by_score = deniro_data.sort_values(["Score"], ascending=False)
deniro_sorted_by_score
# Out:
#     Year  Score                                    Title
# 19  1987    100  Dear America: Letters Home From Vietnam
# 8   1976     99                              Taxi Driver
# 17  1985     98                                   Brazil
# 4   1973     98                             Mean Streets
# 12  1980     97                              Raging Bull
# ..   ...    ...                                      ...
# 82  2014      9                              The Bag Man
# 79  2013      7                          The Big Wedding
# 73  2011      7                           New Year's Eve
# 57  2003      4                                  Godsend
# 60  2005      4               The Bridge of San Luis Rey
#
# [87 rows x 3 columns]

# %%
deniro_grouped_by_year = deniro_sorted_by_score.groupby("Year")
deniro_grouped_by_year = deniro_grouped_by_year.count()
deniro_grouped_by_year
# Out:
#       Score  Title
# Year
# 1968      1      1
# 1970      2      2
# 1971      1      1
# 1973      2      2
# 1974      1      1
# 1976      2      2
# 1977      2      2
# 1978      1      1
# 1980      1      1
# 1981      1      1
# 1983      1      1
# 1984      2      2
# 1985      1      1
# 1986      1      1
# 1987      3      3
# 1988      1      1
# 1989      2      2
# 1990      3      3
# 1991      4      4
# 1992      2      2
# 1993      3      3
# 1994      1      1
# 1995      2      2
# 1996      3      3
# 1997      3      3
# 1998      2      2
# 1999      2      2
# 2000      3      3
# 2001      2      2
# 2002      2      2
# 2003      1      1
# 2004      2      2
# 2005      3      3
# 2006      1      1
# 2007      2      2
# 2008      2      2
# 2009      1      1
# 2010      3      3
# 2011      3      3
# 2012      3      3
# 2013      4      4
# 2014      1      1
# 2015      3      3
# 2016      1      1

# %%
deniro_grouped_by_year.sort_values(["Score"], ascending=False)
# Out:
#       Score  Title
# Year
# 1991      4      4
# 2013      4      4
# 2010      3      3
# 1990      3      3
# 1993      3      3
# 1987      3      3
# 1996      3      3
# 1997      3      3
# 2005      3      3
# 2012      3      3
# 2000      3      3
# 2015      3      3
# 2011      3      3
# 1992      2      2
# 1998      2      2
# 1999      2      2
# 2001      2      2
# 1970      2      2
# 2002      2      2
# 1995      2      2
# 1989      2      2
# 2004      2      2
# 2008      2      2
# 1984      2      2
# 1977      2      2
# 1976      2      2
# 1973      2      2
# 2007      2      2
# 2006      1      1
# 2009      1      1
# 2014      1      1
# 1968      1      1
# 2003      1      1
# 1994      1      1
# 1988      1      1
# 1986      1      1
# 1985      1      1
# 1983      1      1
# 1981      1      1
# 1980      1      1
# 1978      1      1
# 1974      1      1
# 1971      1      1
# 2016      1      1

# %%
deniro_data["Year"]
# Out:
# 0     1968
# 1     1970
# 2     1970
# 3     1971
# 4     1973
#       ...
# 82    2014
# 83    2015
# 84    2015
# 85    2015
# 86    2016
# Name: Year, Length: 87, dtype: int64

# %%
list_years = [1992, 1996, 1998, 2005]
body_weight = [1, 6, 45, 50]
plt.plot(list_years, body_weight, "o")
plt.xlabel("years")
plt.ylabel("body weight")
# Out:
# Text(0, 0.5, 'body weight')

# %%
plt.plot(deniro_data["Year"], deniro_data["Score"])

# %%
plt.plot(deniro_grouped_by_year.Score)
